# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from the URL
url = "https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_96.csv"
geburten = pd.read_csv(url, sep=",", encoding="latin1")  # Adjust separator and encoding as needed

# Display the first few rows of the dataset
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>

# %%
data
# Out:
#       ï»¿BFS_NR              GEBIET_NAME                 THEMA_NAME  \
# 0             1              Aeugst a.A.  BevÃ¶lkerung und Soziales
# 1             1              Aeugst a.A.  BevÃ¶lkerung und Soziales
# 2             1              Aeugst a.A.  BevÃ¶lkerung und Soziales
# 3             1              Aeugst a.A.  BevÃ¶lkerung und Soziales
# 4             1              Aeugst a.A.  BevÃ¶lkerung und Soziales
# ...         ...                      ...                        ...
# 6619          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales
# 6620          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales
# 6621          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales
# 6622          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales
# 6623          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales
#
#                    SET_NAME                SUBSET_NAME  INDIKATOR_ID  \
# 0     BevÃ¶lkerungsbewegung  Geburten und SterbefÃ¤lle            96
# ...

# %%
url = "https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_371.csv"
EFH = pd.read_csv(url, sep=",", encoding="latin1")
EFH
# Out:
#        ï»¿BFS_NR              GEBIET_NAME          THEMA_NAME  \
# 0              1              Aeugst a.A.  Bau und Immobilien
# 1              1              Aeugst a.A.  Bau und Immobilien
# 2              1              Aeugst a.A.  Bau und Immobilien
# 3              1              Aeugst a.A.  Bau und Immobilien
# 4              1              Aeugst a.A.  Bau und Immobilien
# ...          ...                      ...                 ...
# 10130          0  ZÃ¼rich - ganzer Kanton  Bau und Immobilien
# 10131          0  ZÃ¼rich - ganzer Kanton  Bau und Immobilien
# 10132          0  ZÃ¼rich - ganzer Kanton  Bau und Immobilien
# 10133          0  ZÃ¼rich - ganzer Kanton  Bau und Immobilien
# 10134          0  ZÃ¼rich - ganzer Kanton  Bau und Immobilien
#
#                            SET_NAME        SUBSET_NAME  INDIKATOR_ID  \
# 0      Wohnungen, WohnbautÃ¤tigkeit  WohnbautÃ¤tigkeit           371
# 1      Wohnungen, WohnbautÃ¤tigkeit  WohnbautÃ¤tigkeit           371
# ...

# %%
Geburtenrate1000 = pd.read_csv("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_97.csv", sep=",", encoding="latin1")
KindergartenAnz = pd.read_csv("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_143.csv", sep=",", encoding="latin1")
Wegzüge = pd.read_csv("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_253.csv", sep=",", encoding="latin1")
Anteilunter14 = pd.read_csv("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_81.csv", sep=",", encoding="latin1")
Bevölkerungszunahme = pd.read_csv("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_200.csv", sep=",", encoding="latin1")

# %%
bau583od5831 = pd.read_csv('/mnt/data/bau583od5831.csv', encoding="latin1")
kennzahlen_kitas_seit2006 = pd.read_csv('/mnt/data/kennzahlen_kitas_seit2006.csv', encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-7901b0c3db68> in <cell line: 1>()
# ----> 1 bau583od5831 = pd.read_csv('/mnt/data/bau583od5831.csv', encoding="latin1")
#       2 kennzahlen_kitas_seit2006 = pd.read_csv('/mnt/data/kennzahlen_kitas_seit2006.csv', encoding="latin1")
#
# ...

# %%
Kindergarten
# Out:
#       ï»¿BFS_NR              GEBIET_NAME                 THEMA_NAME SET_NAME  \
# 0             1              Aeugst a.A.  BevÃ¶lkerung und Soziales  Bildung
# 1             1              Aeugst a.A.  BevÃ¶lkerung und Soziales  Bildung
# 2             1              Aeugst a.A.  BevÃ¶lkerung und Soziales  Bildung
# 3             1              Aeugst a.A.  BevÃ¶lkerung und Soziales  Bildung
# 4             1              Aeugst a.A.  BevÃ¶lkerung und Soziales  Bildung
# ...         ...                      ...                        ...      ...
# 6609          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales  Bildung
# 6610          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales  Bildung
# 6611          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales  Bildung
# 6612          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales  Bildung
# 6613          0  ZÃ¼rich - ganzer Kanton  BevÃ¶lkerung und Soziales  Bildung
#
# ...
